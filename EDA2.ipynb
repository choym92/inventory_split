# %%
import pandas as pd
import numpy as np

from IPython.display import display, HTML, display_html            # display output
pd.set_option('display.max_rows', 200)                             # display 200 max_rows
pd.set_option('display.max_columns', 50)                           # display 200 max_rows

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


import warnings                                                    # do not disturbe` mode
warnings.filterwarnings('ignore')

# https://medium.com/open-machine-learning-course/open-machine-learning-course-topic-9-time-series-analysis-in-python-a270cb05e0b3

# %%
# import data
df = pd.read_csv('./Data/inventory_split.csv')

# %% [markdown]
# Forecast quality metrics:
# Before actually forecasting, let's understand how to measure the quality of predictions and have a look at the most common and widely used metrics.
#
# 	- R squared: coefficient determination (in econometrics, it can be interpreted as a percentage of variance explained by the model) (-inf,1]
# 	- Mean Absolute Error: it is an interpretable metric because it has the same unit of measurements as the initial series [0, +inf)
# 	- Median Absolute Error: an interpretable metric, particularly interesting because it is robust to outliers, [0, +inf)
# 	- Mean Squared Error: most commonly used, gives higher penalty to big mistakes and vice versa, [0, +inf)
# 	- Mean Squared Logarithmic Error: practically the same as MSE but we initially take logarithm of the series, as a result we give attention to small mistakes as well, usually is used when data has exponential trends. [0, +inf)
# 	- Mean Absolute Percentage Error: same as MAE but percentage, very convenient when you want to explain the quality of the model to your management [0, +inf), not implemented in sklearn

# %%
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error              # R2, MedianAE, MAE
from sklearn.metrics import  mean_squared_error, mean_squared_log_error                       # MSE, MSLE

def mean_absolute_percentage_error(y_true, y_pred):                                           # MAPE
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def moving_average(series, n):                                                                # Moving Avg
    """
        Calculate average of last n observations
    """
    return np.average(series[-n:])

# %% [markdown]
# # SKUs Analysis

# %% [markdown]
# Top 3 SKUs

# %%
TopSKU = df.pivot_table(values='Order qty', index='Description', aggfunc = lambda x: x.sum()).sort_values(by='Order qty', ascending=False)
Top3SKU = TopSKU.index[:3].to_list()

# %% [markdown]
# Total Order Qty of #1 SKU

# %%
Total0 = df[df['Description'].isin([Top3SKU[0]])].pivot_table(values='Order qty',index=['Document date'], aggfunc = lambda x: x.sum())
# Total0.drop(Total0.tail(1).index, inplace=True)       # Drop Last Row

# %%
def to_daily_ts(df):
    df.rename(columns = {list(Total0)[0]:'ts'}, inplace=True)            # first column name to ts
    df.index.names = ['ds']                                              # index = ds
    df.index = pd.to_datetime(df.index)                                  # index to datetime
    df = df.asfreq(freq='1D')                                            # Set frequency of time series
    df.sort_index(ascending = True, inplace=True)                        # Sort by date (index)
    df.fillna(value=0, inplace=True)
    return df

# %%
dailyTotal = to_daily_ts(Total0)

# %% [markdown]
# USJ7 Order Qty of #1 SKU

# %%
# USJ70 = df[df['Description'].isin([Top3SKU[0]])].pivot_table(values='Order qty',index=['Actual Goods Issue Year Period'], columns = 'Plant', aggfunc = lambda x: x.sum())['USJ7']
# USJ70=USJ70.to_frame()
# USJ70.drop(USJ70.tail(1).index,inplace=True)

# %%
USJ70 = df[df['Description'].isin([Top3SKU[0]])].pivot_table(values='Order qty',index=['Document date'], columns = 'Plant', aggfunc = lambda x: x.sum())['USJ7']
USJ70=USJ70.to_frame()
dailyUSJ70 = to_daily_ts(USJ70)

# %%
plt.figure(figsize = (15,7))
plt.plot(Total0)
plt.title('(Total) Shipment of: UB READY RICE SPECIALTY JASMINE 12/240G')
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

plt.figure(figsize = (15,7))
plt.plot(USJ70)
plt.title('(USJ7) Shipment of: UB READY RICE SPECIALTY JASMINE 12/240G')
plt.grid(True)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 1) Moving Average / Rolling Mean

# %% [markdown]
# `DataFrame.rolling(window).mean()`: <br>
# The wider the window - the smoother will be the trend. In the case of the very noisy data, which can be very often encountered in finance, this procedure can help to detect common patterns.

# %%
def plotMovingAverage(series, window, plot_intervals=False, scale=1.96, plot_anomalies=False):
    '''
        series - dataframe with timeseries
        window - rolling window size
        plot_intervals - show confidence intervals
        plot_anomalies - show anomalies
    
    '''
    
    rolling_mean = series.rolling(window=window).mean()
    
    plt.figure(figsize=(15,5))
    plt.title("Moving Average \n window size ={}".format(window))
    plt.plot(rolling_mean, "g", label = "Rolling Mean Trend")
    
    # Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bond = rolling_mean - (mae + scale * deviation)
        upper_bond = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bond, "r--", label="upper Bond / Lower Bond")
        plt.plot(lower_bond, "r--")
        
        # having the intervals, find abnormal values
        if plot_anomalies:
            anomalies = pd.DataFrame(index=series.index, columns = series.columns)
            anomalies[series<lower_bond] = series[series<lower_bond]
            anomalies[series>upper_bond] = series[series>upper_bond]
            plt.plot(anomalies, 'ro', markersize = 10)
            print(series[anomalies.notna().values])
    plt.plot(series[window:], label="Actual Values")
    plt.legend(loc="upper left")
    plt.grid(True)
    plt.xticks(rotation=90)

# %%
# smoothing by last 2 Periods
plotMovingAverage(USJ70,2)
# ....extra
plotMovingAverage(USJ70,4)
plotMovingAverage(USJ70,8)

# %%
# Plotting Confidence Interval
plotMovingAverage(USJ70, 2,plot_intervals = True)
# Lets see if we catch anomaly
plotMovingAverage(USJ70, 2, plot_intervals=True, plot_anomalies=True)
# Out:
#                                  USJ7
# Actual Goods Issue Year Period
# 2019P05                         21823

# %% [markdown]
# # 1-a) Weighted Moving Average
#
# **Weighted average**: is a simple modification of the moving average, inside of which observations have different weights summing up to one, usually more recent observations have greater weight.

# %%
def weighted_average(series, weights):
    """
        Calculate weighter average on series
        weight: List of weight ratio
    """
    result = 0.0
    weights.reverse()                  # reverses the list,inplace=True 
    for n in range(len(weights)):
        result += series.iloc[-n-1] * weights[n]
    return float(result)
  
weighted_average(USJ70, [0.6, 0.3, 0.1])
# Out:
# 8950.599999999999

# %% [markdown]
# # 2) Exponential Smoothing: A bit more complex model
#
# **Exponential smoothing**: <br>
# And now let’s take a look at what happens if instead of weighting the last nn values of the time series we start weighting all available observations while exponentially decreasing weights as we move further back in historical data. There’s a formula of the simple exponential smoothing that will help us in that:

# %%
def exponential_smoothing(series, alpha):
    """
        series - dataset with timestamps
        alpha - float [0.0, 1.0], smoothing parameter
    """
    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return result
    
def plotExponentialSmoothing(series, alphas):
    """
        Plots exponential smoothing with different alphas
        
        series - dataset with timestamps
        alphas - list of floats, smoothing parameters
        
    """
    with plt.style.context('seaborn-white'):    
        plt.figure(figsize=(15, 7))
        for alpha in alphas:
            plt.plot(exponential_smoothing(series, alpha), label="Alpha {}".format(alpha))
        plt.plot(series.values, "c", label = "Actual")
        plt.legend(loc="best")
        plt.axis('tight')
        plt.title("Exponential Smoothing")
        plt.grid(True);
        
        
plotExponentialSmoothing(USJ70.USJ7, [0.3, 0.05])

# %% [markdown]
# # 2-a) Double exponential smoothing
# #### Double Exponential Smoothing
# A single future point prediction is not enough, so let's extend exponential smoothing so we can predict two future points.
# <br>
# Series decomposition should help us- obtain two components: intercept (also level) l and trend (also slope) b. We learn to predict intercept (or expected series value) using previous methods. We apply the same exponential smoothing to the trend, believing naively
#
#
#
# As a result we get a set of functions. The first one describes intercept, as before it depends on the current value of the series, and the second term is now split into previous values of the level and of the trend. The second function describes trend — it depends on the level changes at the current step and on the previous value of the trend. In this case β coefficient is a weight in the exponential smoothing. The final prediction is the sum of the model values of the intercept and trend.

# %%
def double_exponential_smoothing(series, alpha, beta):
    """
        series - dataset with timeseries
        alpha - float [0.0, 1.0], smoothing parameter for level
        beta - float [0.0, 1.0], smoothing parameter for trend
    """
    # first value is same as series
    result = [series[0]]
    for n in range(1, len(series)+1):
        if n == 1:
            level, trend = series[0], series[1] - series[0]
        if n >= len(series): # forecasting
            value = result[-1]
        else:
            value = series[n]
        last_level, level = level, alpha*value + (1-alpha)*(level+trend)
        trend = beta*(level-last_level) + (1-beta)*trend
        result.append(level+trend)
    return result

def plotDoubleExponentialSmoothing(series, alphas, betas):
    """
        Plots double exponential smoothing with different alphas and betas
        
        series - dataset with timestamps
        alphas - list of floats, smoothing parameters for level
        betas - list of floats, smoothing parameters for trend
    """
    
    with plt.style.context('seaborn-white'):    
        plt.figure(figsize=(20, 8))
        for alpha in alphas:
            for beta in betas:
                plt.plot(double_exponential_smoothing(series, alpha, beta), label="Alpha {}, beta {}".format(alpha, beta))
        plt.plot(series.values, label = "Actual")
        plt.legend(loc="best")
        plt.axis('tight')
        plt.title("Double Exponential Smoothing")
        plt.grid(True)
        
        
plotDoubleExponentialSmoothing(USJ70.USJ7, alphas = [0.9, 0.1], betas=[0.9,0.1])

# %% [markdown]
# Now we have to tune two parameters — α and β. The former is responsible for the series smoothing around trend, and the latter for the smoothing of the trend itself. The bigger the values, the more weight the latest observations will have and the less smoothed the model series will be. Combinations of the parameters may produce really weird results, especially if set manually. We’ll look into choosing parameters automatically in a bit, immediately after triple exponential smoothing.

# %% [markdown]
# # 2-b) Triple Exponential Smoothing
# #### Triple Exponential Smoothing a.k.a Holt-Winters
# The idea of this method is that we add another, third component **seasonality**. This means we shouldn't use the method if our time series do not have seasonality, which is not the case in our example. Seasonal components in the model will explain repeated variation around intercept and trend, and it will be described by the length of the season, in other words by the period after which variations repeat. For each observation in the season there's seperate component, for example, if the length of the season is 7 (weekly seasonality), we will have 7 seasonal components, one for each day of the week.
#
# Intercept now depends on the current value of the series minus corresponding seasonal component, trend stays unchanged, and the seasonal component depends on the current value of the series minus intercept and on the previous value of the component. Please take into account that the component is smoothed through all the available seasons, for example, if we have a Monday component then it will only be averaged with other Mondays. You can read more on how averaging works and how initial approximation of the trend and seasonal components is done here. Now that we have seasonal component we can predict not one and not even two but arbitrary mm future steps which is very encouraging.
# Below is the code for a triple exponential smoothing model, also known by the last names of its creators — Charles Holt and his student Peter Winters. Additionally Brutlag method was included into the model to build confidence intervals:
#
#
# where T is the length of the season, d is the predicted deviation, and the other parameters were taken from the triple exponential smoothing. You can read more about the method and its applicability to anomalies detection in time series here.

# %%
class HoltWinters:
    
    """
    Holt-Winters model with the anomalies detection using Brutlag method
    
    # series - initial time series
    # slen - length of a season
    # alpha, beta, gamma - Holt-Winters model coefficients
    # n_preds - predictions horizon
    # scaling_factor - sets the width of the confidence interval by Brutlag (usually takes values from 2 to 3)
    
    """
    
    
    def __init__(self, series, slen, alpha, beta, gamma, n_preds, scaling_factor=1.96):
        self.series = series
        self.slen = slen
        self.alpha = alpha
        self.beta = beta
        self.gamma = gamma
        self.n_preds = n_preds
        self.scaling_factor = scaling_factor
        
        
    def initial_trend(self):
        sum = 0.0
        for i in range(self.slen):
            sum += float(self.series[i+self.slen] - self.series[i]) / self.slen
        return sum / self.slen  
    
    def initial_seasonal_components(self):
        seasonals = {}
        season_averages = []
        n_seasons = int(len(self.series)/self.slen)
        # let's calculate season averages
        for j in range(n_seasons):
            season_averages.append(sum(self.series[self.slen*j:self.slen*j+self.slen])/float(self.slen))
        # let's calculate initial values
        for i in range(self.slen):
            sum_of_vals_over_avg = 0.0
            for j in range(n_seasons):
                sum_of_vals_over_avg += self.series[self.slen*j+i]-season_averages[j]
            seasonals[i] = sum_of_vals_over_avg/n_seasons
        return seasonals   

          
    def triple_exponential_smoothing(self):
        self.result = []
        self.Smooth = []
        self.Season = []
        self.Trend = []
        self.PredictedDeviation = []
        self.UpperBond = []
        self.LowerBond = []
        
        seasonals = self.initial_seasonal_components()
        
        for i in range(len(self.series)+self.n_preds):
            if i == 0: # components initialization
                smooth = self.series[0]
                trend = self.initial_trend()
                self.result.append(self.series[0])
                self.Smooth.append(smooth)
                self.Trend.append(trend)
                self.Season.append(seasonals[i%self.slen])
                
                self.PredictedDeviation.append(0)
                
                self.UpperBond.append(self.result[0] + 
                                      self.scaling_factor * 
                                      self.PredictedDeviation[0])
                
                self.LowerBond.append(self.result[0] - 
                                      self.scaling_factor * 
                                      self.PredictedDeviation[0])
                continue
                
            if i >= len(self.series): # predicting
                m = i - len(self.series) + 1
                self.result.append((smooth + m*trend) + seasonals[i%self.slen])
                
                # when predicting we increase uncertainty on each step
                self.PredictedDeviation.append(self.PredictedDeviation[-1]*1.01) 
                
            else:
                val = self.series[i]
                last_smooth, smooth = smooth, self.alpha*(val-seasonals[i%self.slen]) + (1-self.alpha)*(smooth+trend)
                trend = self.beta * (smooth-last_smooth) + (1-self.beta)*trend
                seasonals[i%self.slen] = self.gamma*(val-smooth) + (1-self.gamma)*seasonals[i%self.slen]
                self.result.append(smooth+trend+seasonals[i%self.slen])
                
                # Deviation is calculated according to Brutlag algorithm.
                self.PredictedDeviation.append(self.gamma * np.abs(self.series[i] - self.result[i]) 
                                               + (1-self.gamma)*self.PredictedDeviation[-1])
                     
            self.UpperBond.append(self.result[-1] + 
                                  self.scaling_factor * 
                                  self.PredictedDeviation[-1])

            self.LowerBond.append(self.result[-1] - 
                                  self.scaling_factor * 
                                  self.PredictedDeviation[-1])

            self.Smooth.append(smooth)
            self.Trend.append(trend)
            self.Season.append(seasonals[i%self.slen])

# %% [markdown]
# ## Time series cross validation
# Before we start building model let’s talk first about how to estimate model parameters automatically. <br><br>
# There’s nothing unusual here, as always we have to choose a loss function suitable for the task, that will tell us how close the model approximates data. Then using cross-validation we will evaluate our chosen loss function for given model parameters, calculate gradient, adjust model parameters and so forth, bravely descending to the global minimum of error. <br><br>
# The question is how to do cross-validation on time series, because, you know, **time series do have time structure and one just can’t randomly mix values in a fold without preserving this structure, otherwise all time dependencies between observations will be lost.** That’s why we will have to use a bit more tricky approach to optimization of the model parameters, I don’t know if there’s an official name to it but on CrossValidated, where one can find all the answers but the Answer to the Ultimate Question of Life, the Universe, and Everything, “cross-validation on a rolling basis” was proposed as a name.<br><br>
#
# The idea is rather simple — we train our model on a small segment of the time series, from the beginning until some t, make predictions for the next t+n steps and calculate an error. Then we expand our training sample until t+n value and make predictions from t+n until t+2∗n, and we continue moving our test segment of the time series until we hit the last available observation. As a result we have as many folds as many n will fit between the initial training sample and the last observation.
#
# ![image.png](attachment:image.png)
#
# Now, knowing how to set cross-validation, we will find optimal parameters for the Holt-Winters model,
# `slen=2`
# recall that we have daily seasonality in ads, hence the `slen=24` parameter

# %%
from sklearn.model_selection import TimeSeriesSplit # you have everything done for you

def timeseriesCVscore(params, series, loss_function=mean_squared_error, slen=2):
    """
        Returns error on CV  
        
        params - vector of parameters for optimization
        series - dataset with timeseries
        slen - season length for Holt-Winters model
    """
    # errors array
    errors = []
    
    values = series.values
    alpha, beta, gamma = params
    
    # set the number of folds for cross-validation
    tscv = TimeSeriesSplit(n_splits=3) 
    
    # iterating over folds, train model on each, forecast and calculate error
    for train, test in tscv.split(values):

        model = HoltWinters(series=values[train], slen=slen, 
                            alpha=alpha, beta=beta, gamma=gamma, n_preds=len(test))
        model.triple_exponential_smoothing()
        
        predictions = model.result[-len(test):]
        actual = values[test]
        error = loss_function(predictions, actual)
        errors.append(error)
        
    return np.mean(np.array(errors))

# %% [markdown]
# In the Holt-Winters model, as well as in the other models of exponential smoothing, there’s a constraint on how big smoothing parameters could be, each of them is in the range from 0 to 1, therefore to minimize loss function we have to choose an algorithm that supports constraints on model parameters, in our case — Truncated Newton conjugate gradient.

# %%
# %%time
from scipy.optimize import minimize   
data = USJ70.USJ7[:-7] # leave some data for testing

# initializing model parameters alpha, beta, and gamma
x = [0,0,0]

# minimizing the loss function
opt = minimize(timeseriesCVscore, x0=x,
              args=(data, mean_squared_log_error),
              method = "TNC", bounds = ((0,1),(0,1),(0,1))
              )
# take optimal values...
alpha_final, beta_final, gamma_final = opt.x
print(alpha_final, beta_final, gamma_final)

# ...and train the model with them, forecasting the next 50 hours
model = HoltWinters(data, slen = 12,
                   alpha = alpha_final,
                   beta= beta_final,
                   gamma = gamma_final,
                   n_preds = 7,
                   scaling_factor = 2)

model.triple_exponential_smoothing()
# Out:
# 0.5463579425655198 0.5009976598569443 1.0
# Wall time: 761 ms

# %%
def plotHoltWinters(series, plot_intervals=False, plot_anomalies=False):
    """
        series - dataset with timeseries
        plot_intervals - show confidence intervals
        plot_anomalies - show anomalies 
    """
    
    plt.figure(figsize=(20, 10))
    plt.plot(model.result, label = "Model")
    plt.plot(series.values, label = "Actual")
    error = mean_absolute_percentage_error(series.values, model.result[:len(series)])
    plt.title("Mean Absolute Percentage Error: {0:.2f}%".format(error))
    
    if plot_anomalies:
        anomalies = np.array([np.NaN]*len(series))
        anomalies[series.values<model.LowerBond[:len(series)]] = \
            series.values[series.values<model.LowerBond[:len(series)]]
        anomalies[series.values>model.UpperBond[:len(series)]] = \
            series.values[series.values>model.UpperBond[:len(series)]]
        plt.plot(anomalies, "o", markersize=10, label = "Anomalies")
    
    if plot_intervals:
        plt.plot(model.UpperBond, "r--", alpha=0.5, label = "Up/Low confidence")
        plt.plot(model.LowerBond, "r--", alpha=0.5)
        plt.fill_between(x=range(0,len(model.result)), y1=model.UpperBond, 
                         y2=model.LowerBond, alpha=0.2, color = "grey")    
        
    plt.vlines(len(series), ymin=min(model.LowerBond), ymax=max(model.UpperBond), linestyles='dashed')
    plt.axvspan(len(series)-20, len(model.result), alpha=0.3, color='lightgrey')
    plt.grid(True)
    plt.axis('tight')
    plt.legend(loc="best", fontsize=13);
    
plotHoltWinters(USJ70.USJ7)
plotHoltWinters(USJ70.USJ7, plot_intervals=True, plot_anomalies=True)

# %% [markdown]
# # Conclusion:
#
# Forecasting Order Qty is not so simple using Holt-winters. I should go by something else for simplicity and big fluctuations in the recent trend.

# %%
plt.figure(figsize=(25, 10))
plt.plot(model.PredictedDeviation)
plt.grid(True)
plt.axis('tight')
plt.title("Brutlag's predicted deviation");

# %% [markdown]
# ## Looking at Stationarity

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(df, ts, window = 12):
    """
    Test stationarity using moving average statistics and Dickey-Fuller test
    Source: https://www.analyticsvidhya.com/blog/2016/02/time-series-forecasting-codes-python/
    """
    
    # Determing rolling statistics
    rolmean = df[ts].rolling(window = window, center = False).mean()
    rolstd = df[ts].rolling(window = window, center = False).std()
    
    # Plot rolling statistics:
    plt.figure(figsize=(15, 7))
    orig = plt.plot(df[ts], 
                    color = 'blue', 
                    label = 'Original')
    mean = plt.plot(rolmean, 
                    color = 'red', 
                    label = 'Rolling Mean')
    std = plt.plot(rolstd, 
                   color = 'black', 
                   label = 'Rolling Std')
    plt.legend(loc = 'best')
    plt.title('Rolling Mean & Standard Deviation for %s' %(ts))
    plt.xticks(rotation = 90)
    plt.show(block = False)
    plt.close()
    
    # Perform Dickey-Fuller test:
    # Null Hypothesis (H_0): time series is not stationary
    # Alternate Hypothesis (H_1): time series is stationary
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(df[ts], 
                      autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], 
                         index = ['Test Statistic',
                                  'p-value',
                                  '# Lags Used',
                                  'Number of Observations Used'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
test_stationarity(df = USJ70, ts = 'USJ7', window = 4)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.572072
# p-value                         0.497606
# # Lags Used                     0.000000
# Number of Observations Used    33.000000
# Critical Value (1%)            -3.646135
# Critical Value (5%)            -2.954127
# Critical Value (10%)           -2.615968
# dtype: float64

# %%
def plot_transformed_data(df, ts, ts_transform):
    """
    Plot transformed and original time series data
    """
    # Plot time series data
    f, ax = plt.subplots(1,1)
    ax.plot(df[ts])
    ax.plot(df[ts_transform], color = 'red')

    # Add title
    ax.set_title('%s and %s time-series graph' %(ts, ts_transform))

    # Rotate x-labels
    ax.tick_params(axis = 'x', rotation = 90)

    # Add legend
    ax.legend([ts, ts_transform])

    plt.show()
    plt.close()

    return

# %%
df_example = USJ70.copy()
df_example.rename(columns = {'USJ7': 'ts'}, inplace=True)
df_example.index.names = ['ds']

# %%
# Transformation - log ts
df_example['ts_log'] = df_example['ts'].apply(lambda x: np.log(x))

# Transformation - 7-day moving averages of log ts
df_example['ts_log_moving_avg'] = df_example['ts_log'].rolling(window = 3,
                                                               center = False).mean()

# Transformation - 7-day moving average ts
df_example['ts_moving_avg'] = df_example['ts'].rolling(window = 3,
                                                       center = False).mean()

# Transformation - Difference between logged ts and first-order difference logged ts
# df_example['ts_log_diff'] = df_example['ts_log'] - df_example['ts_log'].shift()
df_example['ts_log_diff'] = df_example['ts_log'].diff()

# Transformation - Difference between ts and moving average ts
df_example['ts_moving_avg_diff'] = df_example['ts'] - df_example['ts_moving_avg']

# Transformation - Difference between logged ts and logged moving average ts
df_example['ts_log_moving_avg_diff'] = df_example['ts_log'] - df_example['ts_log_moving_avg']

# Transformation - Difference between logged ts and logged moving average ts
df_example_transform = df_example.dropna()

# Transformation - Logged exponentially weighted moving averages (EWMA) ts
df_example_transform['ts_log_ewma'] = df_example_transform['ts_log'].ewm(halflife = 7,
                                                                         ignore_na = False,
                                                                         min_periods = 0,
                                                                         adjust = True).mean()

# Transformation - Difference between logged ts and logged EWMA ts
df_example_transform['ts_log_ewma_diff'] = df_example_transform['ts_log'] - df_example_transform['ts_log_ewma']

# Display data
display(df_example_transform.head())

# Plot data
plot_transformed_data(df = df_example, 
                      ts = 'ts', 
                      ts_transform = 'ts_log')
# Plot data
plot_transformed_data(df = df_example, 
                      ts = 'ts_log', 
                      ts_transform = 'ts_log_moving_avg')

# Plot data
plot_transformed_data(df = df_example_transform, 
                      ts = 'ts', 
                      ts_transform = 'ts_moving_avg')

# Plot data
plot_transformed_data(df = df_example_transform, 
                      ts = 'ts_log', 
                      ts_transform = 'ts_log_diff')

# Plot data
plot_transformed_data(df = df_example_transform, 
                      ts = 'ts', 
                      ts_transform = 'ts_moving_avg_diff')

# Plot data
plot_transformed_data(df = df_example_transform, 
                      ts = 'ts_log', 
                      ts_transform = 'ts_log_moving_avg_diff')

# Plot data
plot_transformed_data(df = df_example_transform, 
                      ts = 'ts_log', 
                      ts_transform = 'ts_log_ewma')

# Plot data
plot_transformed_data(df = df_example_transform, 
                      ts = 'ts_log', 
                      ts_transform = 'ts_log_ewma_diff')

# Perform stationarity test
test_stationarity(df = df_example_transform, 
                  ts = 'ts_log')

# Perform stationarity test
test_stationarity(df = df_example_transform, 
                  ts = 'ts_moving_avg')

# Perform stationarity test
test_stationarity(df = df_example_transform, 
                  ts = 'ts_log_moving_avg')

# Perform stationarity test
test_stationarity(df = df_example_transform,
                  ts = 'ts_log_diff')

# Perform stationarity test
test_stationarity(df = df_example_transform,
                  ts = 'ts_moving_avg_diff')

# Perform stationarity test
test_stationarity(df = df_example_transform,
                  ts = 'ts_log_moving_avg_diff')

# Perform stationarity test
test_stationarity(df = df_example_transform, 
                  ts = 'ts_log_ewma')

# Perform stationarity test
test_stationarity(df = df_example_transform,
                  ts = 'ts_log_ewma_diff')
# Out:
#             ts     ts_log  ts_log_moving_avg  ts_moving_avg  ts_log_diff  \
# ds
# 2017P03  37605  10.534892          10.433280   34463.666667    -0.040749
# 2017P04  38104  10.548075          10.552869   38292.666667     0.013182
# 2017P05  34555  10.450308          10.511091   36754.666667    -0.097767
# 2017P06  31328  10.352268          10.450217   34662.333333    -0.098040
# 2017P07  45074  10.716061          10.506212   36985.666667     0.363793
#
#          ts_moving_avg_diff  ts_log_moving_avg_diff  ts_log_ewma  \
# ds
# 2017P03         3141.333333                0.101613    10.534892
# 2017P04         -188.666667               -0.004795    10.541809
# 2017P05        -2199.666667               -0.060784    10.508244
# 2017P06        -3334.333333               -0.097949    10.463282
# 2017P07         8088.333333                0.209849    10.524310
#
#          ts_log_ewma_diff
# ds
# 2017P03          0.000000
# 2017P04          0.006265
# 2017P05         -0.057936
# 2017P06         -0.111014
# 2017P07          0.191751
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.062357
# p-value                         0.259918
# # Lags Used                     2.000000
# Number of Observations Used    29.000000
# Critical Value (1%)            -3.679060
# Critical Value (5%)            -2.967882
# Critical Value (10%)           -2.623158
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.045335
# p-value                         0.030872
# # Lags Used                     1.000000
# Number of Observations Used    30.000000
# Critical Value (1%)            -3.669920
# Critical Value (5%)            -2.964071
# Critical Value (10%)           -2.621171
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.343707
# p-value                         0.608947
# # Lags Used                     9.000000
# Number of Observations Used    22.000000
# Critical Value (1%)            -3.769733
# Critical Value (5%)            -3.005426
# Critical Value (10%)           -2.642501
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.153255
# p-value                         0.223646
# # Lags Used                     1.000000
# Number of Observations Used    30.000000
# Critical Value (1%)            -3.669920
# Critical Value (5%)            -2.964071
# Critical Value (10%)           -2.621171
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.409458
# p-value                         0.010641
# # Lags Used                     0.000000
# Number of Observations Used    31.000000
# Critical Value (1%)            -3.661429
# Critical Value (5%)            -2.960525
# Critical Value (10%)           -2.619319
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -3.064253
# p-value                         0.029314
# # Lags Used                     0.000000
# Number of Observations Used    31.000000
# Critical Value (1%)            -3.661429
# Critical Value (5%)            -2.960525
# Critical Value (10%)           -2.619319
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -2.596666
# p-value                         0.093688
# # Lags Used                     2.000000
# Number of Observations Used    29.000000
# Critical Value (1%)            -3.679060
# Critical Value (5%)            -2.967882
# Critical Value (10%)           -2.623158
# dtype: float64
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.801212
# p-value                         0.379860
# # Lags Used                     2.000000
# Number of Observations Used    29.000000
# Critical Value (1%)            -3.679060
# Critical Value (5%)            -2.967882
# Critical Value (10%)           -2.623158
# dtype: float64

# %%
from dateutil.relativedelta import relativedelta   # working with dates with style
from scipy.optimize import minimize                # for function minimization

import statsmodels.formula.api as smf               # statistics and econometrics
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs

from itertools import product                      # some useful function
from tqdm import tqdm_notebook



def tsplot(y, lags=None, figsize=(12, 7), style='bmh'):
    """
        Plot time series, its ACF and PACF, calculate Dickey–Fuller test
        
        y - timeseries
        lags - how many lags to include in ACF, PACF calculation
    """
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        layout = (2, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        
        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[1]
        ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()
        
tsplot(USJ70.USJ7, lags=12)

# %%
ads_diff = USJ70.USJ7 - USJ70.USJ7.shift(14)
tsplot(ads_diff[14:], lags=13)

# %%
temp = df[df['Description'].isin([Top3SKU[0]])].pivot_table(values='Order qty', index=['Actual Goods Issue Year Period','Description','Plant']\
                                                     ,aggfunc = lambda x: x.sum()).fillna(0)

temp.groupby(level=0).transform(lambda x: x/x.sum())
# Out:
#                                                                               Order qty
# Actual Goods Issue Year Period Description                             Plant
# 2017P01                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.258795
#                                                                        USD3    0.093651
#                                                                        USE2    0.063867
#                                                                        USJ7    0.529913
#                                                                        USV2    0.041271
#                                                                        USV6    0.012503
# 2017P02                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.183348
#                                                                        USD3    0.077216
#                                                                        USE2    0.080199
#                                                                        USJ7    0.602128
#                                                                        USV2    0.047317
#                                                                        USV6    0.009792
# 2017P03                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.251164
#                                                                        USD3    0.125482
#                                                                        USE2    0.063872
#                                                                        USJ7    0.503225
#                                                                        USV2    0.044294
#                                                                        USV6    0.011963
# 2017P04                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.187956
#                                                                        USD3    0.111910
#                                                                        USE2    0.071640
#                                                                        USJ7    0.557777
#                                                                        USV2    0.051893
#                                                                        USV6    0.018825
# 2017P05                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.208061
#                                                                        USD3    0.109352
#                                                                        USE2    0.086923
#                                                                        USJ7    0.548109
#                                                                        USV2    0.031438
#                                                                        USV6    0.016116
# 2017P06                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.221652
#                                                                        USD3    0.115953
#                                                                        USE2    0.066178
#                                                                        USJ7    0.538078
#                                                                        USV2    0.041771
#                                                                        USV6    0.016368
# 2017P07                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.172453
#                                                                        USD3    0.108950
#                                                                        USE2    0.079247
#                                                                        USJ7    0.582607
#                                                                        USV2    0.040651
#                                                                        USV6    0.016092
# 2017P08                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.203028
#                                                                        USD3    0.103655
#                                                                        USE2    0.061082
#                                                                        USJ7    0.563472
#                                                                        USV2    0.050557
#                                                                        USV6    0.018206
# 2017P09                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.193712
#                                                                        USD3    0.106935
#                                                                        USE2    0.099019
#                                                                        USJ7    0.502370
#                                                                        USV2    0.069710
#                                                                        USV6    0.028254
# 2017P10                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.249581
#                                                                        USD3    0.083551
#                                                                        USE2    0.057676
#                                                                        USJ7    0.535133
#                                                                        USV2    0.055518
#                                                                        USV6    0.018542
# 2017P11                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.222079
#                                                                        USD3    0.110249
#                                                                        USE2    0.074106
#                                                                        USJ7    0.528545
#                                                                        USV2    0.039610
#                                                                        USV6    0.025410
# 2017P12                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.240595
#                                                                        USD3    0.107148
#                                                                        USE2    0.072873
#                                                                        USJ7    0.518172
#                                                                        USV2    0.038923
#                                                                        USV6    0.022288
# 2017P13                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.224893
#                                                                        USD3    0.133383
#                                                                        USE2    0.090787
#                                                                        USJ7    0.486456
#                                                                        USV2    0.048927
#                                                                        USV6    0.015553
# 2018P01                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.250971
#                                                                        USD3    0.078413
#                                                                        USE2    0.066475
#                                                                        USJ7    0.525168
#                                                                        USV2    0.056653
#                                                                        USV6    0.022320
# 2018P02                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.224011
#                                                                        USD3    0.125378
#                                                                        USE2    0.092147
#                                                                        USJ7    0.486928
#                                                                        USV2    0.050559
#                                                                        USV6    0.020977
# 2018P03                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.217708
#                                                                        USD3    0.114928
#                                                                        USE2    0.058928
#                                                                        USJ7    0.546335
#                                                                        USV2    0.049639
#                                                                        USV6    0.012463
# 2018P04                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.193857
#                                                                        USD3    0.128356
#                                                                        USE2    0.078043
#                                                                        USJ7    0.522885
# ...                                                                                 ...
# 2018P06                        UB READY RICE SPECIALTY JASMINE 12/240G USE2    0.099190
#                                                                        USJ7    0.491035
#                                                                        USV2    0.048727
#                                                                        USV6    0.025489
# 2018P07                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.167553
#                                                                        USD3    0.103291
#                                                                        USE2    0.058838
#                                                                        USJ7    0.597154
#                                                                        USV2    0.052455
#                                                                        USV6    0.020709
# 2018P08                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.227373
#                                                                        USD3    0.148619
#                                                                        USE2    0.101084
#                                                                        USJ7    0.426209
#                                                                        USV2    0.067443
#                                                                        USV6    0.029272
# 2018P09                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.268078
#                                                                        USD3    0.129105
#                                                                        USE2    0.071856
#                                                                        USJ7    0.453441
#                                                                        USV2    0.056269
#                                                                        USV6    0.021251
# 2018P10                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.168618
#                                                                        USD3    0.139828
#                                                                        USE2    0.086445
#                                                                        USJ7    0.526801
#                                                                        USV2    0.060796
#                                                                        USV6    0.017512
# 2018P11                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.196768
#                                                                        USD3    0.133419
#                                                                        USE2    0.068889
#                                                                        USJ7    0.517317
#                                                                        USV2    0.063243
#                                                                        USV6    0.020364
# 2018P12                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.196675
#                                                                        USD3    0.128588
#                                                                        USE2    0.080428
#                                                                        USJ7    0.508061
#                                                                        USV2    0.068634
#                                                                        USV6    0.017613
# 2018P13                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.253363
#                                                                        USD3    0.149790
#                                                                        USE2    0.076243
#                                                                        USJ7    0.457722
#                                                                        USV2    0.042187
#                                                                        USV6    0.020694
# 2019P01                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.171374
#                                                                        USD3    0.121102
#                                                                        USE2    0.062733
#                                                                        USJ7    0.591529
#                                                                        USV2    0.040385
#                                                                        USV6    0.012876
# 2019P02                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.182436
#                                                                        USD3    0.098011
#                                                                        USE2    0.085746
#                                                                        USJ7    0.563567
#                                                                        USV2    0.050739
#                                                                        USV6    0.019501
# 2019P03                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.215139
#                                                                        USD3    0.076781
#                                                                        USE2    0.097056
#                                                                        USJ7    0.493561
#                                                                        USV2    0.102486
#                                                                        USV6    0.014977
# 2019P04                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.198399
#                                                                        USD3    0.053819
#                                                                        USE2    0.188687
#                                                                        USJ7    0.435463
#                                                                        USV2    0.102835
#                                                                        USV6    0.020796
# 2019P05                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.185393
#                                                                        USD3    0.157271
#                                                                        USE2    0.192129
#                                                                        USJ7    0.285440
#                                                                        USV2    0.131962
#                                                                        USV6    0.047807
# 2019P06                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.312069
#                                                                        USD3    0.166148
#                                                                        USE2    0.154085
#                                                                        USJ7    0.243362
#                                                                        USV2    0.109161
#                                                                        USV6    0.015174
# 2019P07                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.291642
#                                                                        USD3    0.219154
#                                                                        USE2    0.213311
#                                                                        USJ7    0.129213
#                                                                        USV2    0.111961
#                                                                        USV6    0.034719
# 2019P08                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.359404
#                                                                        USD3    0.142170
#                                                                        USE2    0.195210
#                                                                        USJ7    0.145950
#                                                                        USV2    0.119843
#                                                                        USV6    0.037422
# 2019P09                        UB READY RICE SPECIALTY JASMINE 12/240G USC8    0.354343
#                                                                        USD3    0.168550
#                                                                        USE2    0.226514
#                                                                        USJ7    0.090575
#                                                                        USV2    0.126795
#                                                                        USV6    0.033223
#
# [210 rows x 1 columns]

# %%
df[df['Description'].isin([Top3SKU[0]])].pivot_table(values='Order qty',index=['Sold to Party Name','Plant'], aggfunc = lambda x: x.sum()).sort_values(by='Order qty',ascending=False)
# Out:
#                                        Order qty
# Sold to Party Name              Plant
# WAL-MART (EXCL HAWAII)          USJ7      641272
# C & S NORTHEAST (POI)           USC8      213593
# PUBLIX                          USJ7      150549
# PEYTONS 1 (POI)                 USE2      107360
# H E BUTT GROC CO                USJ7       96369
# PEYTONS 1 (POI)                 USJ7       80033
# WAKEFERN FOOD CORP (POI)        USC8       70110
# KING SOOPERS (POI)              USJ7       61488
# FOOD LION (POI)                 USJ7       57153
# TARGET STORES (POI)             USV2       49595
# RALPHS GROCERY CO (POI)         USJ7       42781
# TARGET STORES (POI)             USD3       41318
# PUBLIX                          USE2       41097
# FRED MEYER (POI)                USD3       40894
# TARGET STORES (POI)             USC8       40598
# MEIJER (POI)                    USC8       39126
# WEGMANS FOOD MARKETS (POI)      USC8       36855
# FRY'S FOOD STORES (POI)         USD3       36036
# HANNAFORD BROS CO (POI)         USC8       35700
# HARRIS TEETER (POI)             USE2       35260
# TARGET STORES (POI)             USE2       33936
# ALBERTSONS SOUTHWEST (TOLLESON) USD3       32508
# DEMOULAS SUPERMARKET            USJ7       32424
# SAFEWAY NORTHERN CA (POI)       USD3       32300
# MDV NASH FINCH                  USC8       32172
# PUBLIX ATLANTA                  USJ7       31815
# THE KROGER SOUTHWEST            USJ7       30245
# PEYTONS 1 (POI)                 USV2       25294
# ALBERTSONS COMPANIES LLC        USD3       23583
# COASTAL PACIFIC                 USD3       22638
# C & S NORTHEAST (POI)           USJ7       22321
# HY VEE FOOD STORES              USV2       22239
# TARGET STORES (POI)             USV6       20303
# SMITH'S FD & DRG CTRS (POI)     USD3       19446
# SUPER VALU WEST                 USJ7       19278
# OK GROCERY CO                   USC8       19047
# ROUNDY'S INC (POI)              USV2       18742
# SUPER STORE INDUSTRIES (POI)    USD3       18396
# AMERICAN SEAWAY FOODS (POI)     USC8       18354
# ALBERTSONS ACME (POI)           USJ7       17640
# WINCO FOODS INC DIST CTR (POI)  USD3       17094
# SHAWS BANNER                    USC8       16800
# STATER BROS MARKET (POI)        USD3       15230
# GOLUB CORPORATION (POI)         USC8       14364
# BOZZUTOS INC (POI)              USC8       13251
# WEIS MARKETS (POI)              USC8       13240
# FOOD LION (POI)                 USC8       12993
# SUPER VALU EAST                 USC8       11949
# SAFEWAY SEATTLE (POI)           USD3       11634
# SCHNUCKS MARKET                 USV2       10836
# C & S SOUTHEAST (POI)           USE2       10647
# WAKEFERN FOOD CORP (POI)        USJ7       10395
# C & S NORTHEAST (POI)           USE2        9870
# MDV NASH FINCH                  USE2        9828
# UNITED SUPERMARKET (POI)        USV6        9492
# PUBLIX ATLANTA                  USE2        8946
# MDV NASH FINCH                  USV6        8694
# DEMOULAS SUPERMARKET            USC8        8484
# JEWEL BANNER                    USJ7        8442
#                                 USV2        8190
# ALBERTSONS NORTHWEST (POI)      USD3        7875
# MERCHANTS DISTR INC             USE2        7476
# SMART & FINAL IRIS CO           USJ7        7455
# MID-MOUNTAIN FOODS INC (POI)    USC8        7182
# SUPER VALU EAST                 USJ7        7140
# SAFEWAY DENVER (POI)            USV6        7098
# CERTCO INC (POI)                USV2        6531
# KRASDALE FOODS INC              USJ7        6034
# RANDALL'S FOOD & DRUG LP        USV6        5880
# SUPER VALU MIDWEST REGION       USV2        5880
# AMAZON.COM                      USC8        5870
# DILLON STORES (POI)             USV2        5607
# SPARTAN STORES INC (POI)        USV2        5355
# SUPER VALU WEST                 USV2        5250
# HANNAFORD BROS CO (POI)         USJ7        5124
# NASH FINCH POI HDQ              USC8        4662
# HEINENS INC (POI)               USC8        4620
# ASSOCIATED FOOD STORES (POI)    USD3        4536
# BROOKSHIRE GROC CO (POI)        USV6        4482
# ASSOCIATED WHLSE GROC (POI)     USV2        4284
# AMAZON.COM                      USV2        3973
# ASSOCIATED GROCERS MIAMI (POI)  USE2        3906
# ALBERTSONS ACME (POI)           USC8        3906
# ALBERTSONS INTERMOUNTAIN (POI)  USD3        3738
# AMAZON.COM                      USD3        3532
# ALBERTSONS COMPANIES LLC        USJ7        3528
# FRY'S FOOD STORES (POI)         USJ7        3402
# ASSOCIATED GROCERS MANCHESTER   USC8        3171
# C & S CALIFORNIA (POI)          USE2        3129
# SAFEWAY PHOENIX (POI)           USD3        3087
# SUPER VALU                      USE2        3003
# HARRIS TEETER (POI)             USJ7        2982
# MDV NASH FINCH                  USV2        2793
# GENERAL TRADING CO (POI)        USC8        2772
# FAREWAY WHLSE GROC CO (POI)     USV2        2730
# MARCS (POI)                     USJ7        2520
# GELSON'S MARKETS                USD3        2373
# BASHAS DISTR CENTER             USD3        2226
# VONS (POI)                      USD3        1953
# RALPHS GROCERY CO (POI)         USD3        1722
# Butterfield & Vallis            USC8        1620
# MINER'S INC                     USV2        1575
# SAFEWAY SEATTLE (POI)           USC8        1512
# U R M STORES INC (POI)          USD3        1407
# GORDON FOOD SVC (POI)           USJ7        1407
# SAFEWAY, INC 6551               USJ7        1407
# RANDALL'S FOOD & DRUG LP        USJ7        1218
# WINCO FOODS INC DIST CTR (POI)  USV6        1134
# SUPER VALU CENTRAL REGION (POI) USV2        1050
# MEIJER (POI)                    USJ7        1014
# ASSOCIATED WHLSE GROC (POI)     USV6         924
# FRED MEYER (POI)                USJ7         903
# SAFEWAY SEATTLE (POI)           USV6         840
# DOT FOODS INC (POI)             USJ7         830
# STATER BROS MARKET (POI)        USJ7         798
# ASSOCIATED GROCERS BIRMINGHAM   USE2         714
# AFFILIATED FOODS INC TX (POI)   USV6         672
# HY VEE FOOD STORES              USJ7         630
# FOOD LION (POI)                 USV2         600
# ASSOCIATED WHLSE GROC (POI)     USE2         580
# SMITH'S FD & DRG CTRS (POI)     USJ7         567
# ASSOCIATED GROCERS INC (POI)    USE2         546
# MARCS (POI)                     USC8         504
# SAFEWAY NORTHERN CA (POI)       USJ7         504
# BOZZUTOS INC (POI)              USJ7         504
# OLEAN WHLSE GROC COOP INC       USC8         462
# SCHNUCKS MARKET                 USJ7         462
# UNIFIED GROCERS NO CAL (POI)    USD3         441
# W LEE FLOWERS & CO (POI)        USE2         440
# WEGMANS FOOD MARKETS (POI)      USJ7         420
# R F OWENS CO INC (POI)          USC8         420
# AMAZON PRIME PANTRY (POI)       USV2         388
# ALBERTSONS SOUTHWEST (TOLLESON) USJ7         378
# UNIFIED GROCERS SO CAL (POI)    USD3         378
# CENTRAL GROCERS CO-OP (POI)     USV2         378
# AMAZON.COM                      USV6         339
# MEIJER (POI)                    USV2         336
# ASSOCIATED WHLSE GROC INC       USV2         336
# AMAZON.COM                      USJ7         301
# AMAZON PRIME PANTRY (POI)       USC8         273
# AMERICAN SEAWAY FOODS (POI)     USJ7         273
# INGLES MARKET (POI)             USE2         252
# ALBERTSONS NORTHWEST (POI)      USJ7         252
# MINER'S INC                     USC8         252
# AMAZON PRIME PANTRY (POI)       USD3         233
#                                 USV6         224
# NASH FINCH POI HDQ              USV2         210
# RANDALL'S FOOD & DRUG LP        USE2         210
# MITCHELL GROC CORP (POI)        USE2         189
# ASSOCIATED WHLSE GROC INC       USE2         185
# OK GROCERY CO                   USJ7         168
# SUPER VALU CENTRAL REGION (POI) USD3         168
# Martijn Trading Co., Ltd.       USE2         136
# RANDALLS FOOD & DRUG            USV6         126
# UNITED SUPERMARKET (POI)        USJ7         126
# KRASDALE FOODS INC              USC8         126
# LAUREL GROCERY CO (POI)         USE2         126
# SUPER STORE INDUSTRIES (POI)    USJ7         126
# KING SOOPERS (POI)              USD3         126
# SAFEWAY PHOENIX (POI)           USJ7         126
# ALBERTSONS NORTHWEST (POI)      USV6         126
# SHAWS BANNER                    USJ7          84
# ALBERTSONS INTERMOUNTAIN (POI)  USJ7          84
# DILLON STORES (POI)             USJ7          63
# CENTRAL GROCERS CO-OP (POI)     USJ7          63
# AFFILIATED FOODS INC TX (POI)   USE2          42
# SUPER VALU MIDWEST REGION       USJ7          42
# L.J. Williams Limited           USJ7          25
# GREAT LAKES FOODS (POI)         USV2          21
# AMAZON.COM                      USE2          17
# AMAZON PRIME PANTRY (POI)       USE2           6

# %%
temp = df[df['Description'].isin(Top3SKU)].pivot_table(values='Order qty', index=['Actual Goods Issue Year Period','Description']\
                                                     ,columns='DC',aggfunc = lambda x: x.sum()).fillna(0)
temp = temp.loc[:,temp.columns].div(temp.sum(axis=1), axis=0)
temp
# Out:
# DC                                                                          USC8  \
# Actual Goods Issue Year Period Description
# 2017P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.162389
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.276633
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.264364
# 2017P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.171756
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.227206
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.239865
# 2017P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.208660
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.303715
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.269164
# 2017P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.152415
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.192186
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.212838
# 2017P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.184436
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.238183
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.212445
# 2017P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.143667
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.232678
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.168829
# 2017P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.111753
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.171716
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.171909
# 2017P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.170097
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.231469
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.181392
# 2017P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.198986
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.195501
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.262864
# 2017P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.160655
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.253952
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.201180
# 2017P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.133675
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.231045
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.168162
# 2017P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.201929
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.271824
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.270511
# 2017P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.195916
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.230906
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.247627
# 2018P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.175021
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.263377
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.247801
# 2018P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.144114
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.216054
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.199175
# 2018P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.174264
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.269677
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.245799
# 2018P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.130626
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.208755
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.194436
# 2018P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.175711
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.244505
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.222414
# 2018P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.151007
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.172513
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.220866
# 2018P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.100267
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.180282
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.156645
# 2018P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.173558
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.237938
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.240440
# 2018P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.182023
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.263003
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.270268
# 2018P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.116199
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.198521
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.162375
# 2018P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.167965
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.207234
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.195382
# 2018P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.153961
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.193134
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.239262
# 2018P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.182644
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.257393
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.246920
# 2019P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.122015
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.176386
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.146472
# 2019P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.109299
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.196157
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.180757
# 2019P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.163236
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.220787
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.188341
# 2019P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.179598
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.230908
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.248567
# 2019P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.242964
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.301920
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.365234
# 2019P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.264436
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.331979
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.373976
# 2019P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.198280
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.245085
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.247883
# 2019P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.184409
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.271829
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.258546
# 2019P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.228876
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.300230
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.299749
#
# DC                                                                          USD3  \
# Actual Goods Issue Year Period Description
# 2017P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.076651
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.080153
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.073492
# 2017P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.080225
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.072866
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.074568
# 2017P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.095592
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.080037
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.092410
# 2017P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.091989
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.074377
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.085746
# 2017P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.141492
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.100121
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.117590
# 2017P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.119871
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.110096
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.116890
# 2017P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.065482
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.083641
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.077594
# 2017P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.060794
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.097287
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.114754
# 2017P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.124905
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.108761
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.119492
# 2017P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.119719
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.074113
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.128052
# 2017P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.100348
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.101761
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.080303
# 2017P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.098225
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.092412
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.100946
# 2017P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.156807
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.110589
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.117489
# 2018P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.108140
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.073578
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.084382
# 2018P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.114832
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.090852
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.108721
# 2018P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.120138
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.096160
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.098679
# 2018P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.122268
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.104710
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.107997
# 2018P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.099110
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.089837
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.085087
# 2018P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.126712
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.117854
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.104857
# 2018P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.083100
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.097964
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.069746
# 2018P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.139965
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.110545
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.113685
# 2018P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.105736
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.101308
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.090019
# 2018P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.110273
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.114950
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.098006
# 2018P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.080990
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.112689
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.096207
# 2018P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.138202
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.105078
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.105224
# 2018P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.116213
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.114774
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.092169
# 2019P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.084809
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.095275
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.087808
# 2019P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.085737
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.086715
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.084492
# 2019P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.077149
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.062635
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.101812
# 2019P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.137587
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.082040
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.114000
# 2019P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.146681
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.152052
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.102189
# 2019P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.194605
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.154377
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.144568
# 2019P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.138807
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.167474
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.142525
# 2019P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.158113
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.137784
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.119492
# 2019P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.147291
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.134906
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.117673
#
# DC                                                                          USE2  \
# Actual Goods Issue Year Period Description
# 2017P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.134594
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.161003
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.147560
# 2017P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.105938
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.154540
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.144832
# 2017P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.124648
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.165239
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.156599
# 2017P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.155662
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.174869
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.176658
# 2017P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.129344
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.175195
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.160727
# 2017P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.134134
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.158256
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.166968
# 2017P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.128379
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.187977
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.170156
# 2017P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.112933
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.138934
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.157699
# 2017P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.191617
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.194257
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.182513
# 2017P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.116355
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.143399
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.148441
# 2017P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.158797
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.182974
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.124661
# 2017P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.115261
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.173730
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.139890
# 2017P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.124845
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.192386
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.175498
# 2018P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.099822
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.158277
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.160256
# 2018P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.123236
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.173700
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.190348
# 2018P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.158988
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.193806
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.164074
# 2018P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.133904
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.180155
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.156086
# 2018P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.130315
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.150141
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.162990
# 2018P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.154297
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.227856
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.214637
# 2018P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.118989
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.164241
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.190133
# 2018P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.118452
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.184520
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.169405
# 2018P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.176747
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.173098
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.179374
# 2018P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.111018
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.158843
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.185810
# 2018P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.155317
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.182487
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.194909
# 2018P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.130709
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.201157
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.169780
# 2018P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.100177
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.132499
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.145170
# 2019P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.111193
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.156497
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.162283
# 2019P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.132153
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.178730
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.164192
# 2019P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.099691
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.160522
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.142952
# 2019P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.134638
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.211389
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.177825
# 2019P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.165054
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.229707
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.197892
# 2019P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.159251
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.243883
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.169347
# 2019P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.217271
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.243260
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.244773
# 2019P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.188314
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.226528
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.236820
# 2019P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.184940
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.247609
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.243622
#
# DC                                                                          USJ7  \
# Actual Goods Issue Year Period Description
# 2017P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.301527
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.248840
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.270958
# 2017P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.327300
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.283823
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.246791
# 2017P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.259520
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.222286
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.187552
# 2017P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.285030
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.284056
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.219543
# 2017P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.268124
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.267829
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.227027
# 2017P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.331104
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.277146
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.307364
# 2017P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.474874
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.340498
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.376148
# 2017P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.413371
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.307774
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.368244
# 2017P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.141716
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.209083
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.116588
# 2017P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.297989
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.315328
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.223885
# 2017P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.311279
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.263310
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.381859
# 2017P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.221396
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.226525
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.237047
# 2017P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.263498
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.242744
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.216738
# 2018P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.307452
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.259766
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.227909
# 2018P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.309927
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.259361
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.206777
# 2018P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.221974
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.187534
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.209116
# 2018P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.259979
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.249511
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.232758
# 2018P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.294250
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.264996
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.246275
# 2018P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.243482
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.197512
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.203858
# 2018P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.409644
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.327354
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.336400
# 2018P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.219421
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.183503
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.192764
# 2018P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.220304
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.214543
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.173555
# 2018P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.286859
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.244537
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.273897
# 2018P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.259703
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.252994
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.223191
# 2018P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.237341
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.206243
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.203178
# 2018P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.296559
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.242910
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.265795
# 2019P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.408782
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.376131
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.371969
# 2019P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.436056
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.341656
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.374202
# 2019P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.337478
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.288992
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.267131
# 2019P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.282888
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.248444
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.205140
# 2019P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.007888
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.007416
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.014771
# 2019P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.003338
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.001701
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.012153
# 2019P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.009862
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.006517
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.011762
# 2019P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.005095
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.006792
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.002437
# 2019P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.003758
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.001301
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.004050
#
# DC                                                                          USV2  \
# Actual Goods Issue Year Period Description
# 2017P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.136252
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.100420
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.115778
# 2017P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.160121
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.119414
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.181040
# 2017P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.156045
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.113291
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.148981
# 2017P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.167310
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.147290
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.199777
# 2017P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.097251
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.078501
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.120095
# 2017P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.140785
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.100873
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.139155
# 2017P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.112987
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.093426
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.133760
# 2017P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.128647
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.101127
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.043569
# 2017P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.172810
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.155349
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.183971
# 2017P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.150755
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.097092
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.170579
# 2017P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.179196
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.098866
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.159884
# 2017P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.171181
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.109203
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.143563
# 2017P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.133519
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.099720
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.111564
# 2018P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.120136
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.105478
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.137908
# 2018P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.169268
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.132147
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.182605
# 2018P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.155324
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.129755
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.161900
# 2018P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.157676
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.108335
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.149672
# 2018P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.139588
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.105194
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.165402
# 2018P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.150615
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.114760
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.116521
# 2018P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.162435
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.134690
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.150057
# 2018P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.161403
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.106912
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.143093
# 2018P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.152324
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.109477
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.143147
# 2018P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.208390
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.128664
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.145710
# 2018P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.175347
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.122906
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.180925
# 2018P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.176969
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.141817
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.172020
# 2018P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.157059
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.122379
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.143753
# 2019P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.137888
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.092189
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.121863
# 2019P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.114310
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.091326
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.093073
# 2019P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.155309
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.128225
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.127939
# 2019P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.146033
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.121334
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.161166
# 2019P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.229946
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.147723
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.159947
# 2019P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.185548
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.143127
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.173626
# 2019P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.172569
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.131115
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.161605
# 2019P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.207348
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.152178
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.191729
# 2019P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.235249
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.148642
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.183164
#
# DC                                                                          USV6  \
# Actual Goods Issue Year Period Description
# 2017P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.170474
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.118736
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.126750
# 2017P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.134790
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.119660
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.094890
# 2017P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.144927
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.107055
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.137123
# 2017P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.125524
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.111910
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.090998
# 2017P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.162546
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.114777
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.140006
# 2017P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.117746
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.108430
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.098896
# 2017P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.092343
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.102073
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.056423
# 2017P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.101033
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.101224
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.118091
# 2017P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.134725
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.117945
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.117745
# 2017P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.141154
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.101999
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.115157
# 2017P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.086370
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.090192
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.066957
# 2017P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.166480
# ...
# 2017P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000000
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000000
# 2017P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000635
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000450
# 2017P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000757
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000745
# 2017P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.001837
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000842
# 2017P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000681
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000000
# 2017P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000352
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000611
# 2018P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000000
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000000
# 2018P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.001537
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000247
# 2018P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000608
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000473
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000262
# 2018P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000601
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000000
# 2018P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.001823
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.001066
# 2018P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000000
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000000
# 2018P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.001922
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000252
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000904
# 2018P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000267
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000000
# 2018P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000524
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000229
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000278
# 2018P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.001857
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000200
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.001075
# 2018P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.001710
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000248
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000904
# 2018P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.001082
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000230
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000623
# 2018P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000571
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000000
# 2019P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.002971
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000447
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000952
# 2019P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000206
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000405
# 2019P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000000
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000000
# 2019P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.001680
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000400
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000821
# 2019P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000682
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000830
# 2019P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.005444
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000533
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.002210
# 2019P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000000
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000000
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000000
# 2019P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.000410
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000289
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000000
# 2019P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.001818
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.000803
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.000000
#
# DC                                                                           UV6
# Actual Goods Issue Year Period Description
# 2017P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.018114
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.014215
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.001099
# 2017P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.019870
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.022490
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.018013
# 2017P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.010609
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.008377
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.008170
# 2017P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.022069
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.015312
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.014440
# 2017P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.016806
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.025395
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.022110
# 2017P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.012305
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.012521
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.001898
# 2017P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.014182
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.020668
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.013764
# 2017P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.013124
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.022184
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.016251
# 2017P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.034604
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.019105
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.016377
# 2017P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.012616
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.014117
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.011961
# 2017P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.028498
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.031853
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.017331
# 2017P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.024848
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.018618
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.010086
# 2017P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.010704
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.012850
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.009273
# 2018P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.031827
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.030752
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.027036
# 2018P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.016969
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.021189
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.015498
# 2018P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.021778
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.020074
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.012794
# 2018P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.023815
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.021810
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.018496
# 2018P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.029410
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.026255
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.019508
# 2018P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.020038
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.020902
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.016666
# 2018P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.023063
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.015214
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.014871
# 2018P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.028011
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.026125
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.021456
# 2018P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.017637
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.018952
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.018902
# 2018P10                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.027811
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.034443
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.031525
# 2018P11                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.029069
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.012675
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.004346
# 2018P12                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.033128
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.035687
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.026751
# 2018P13                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.045280
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.038854
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.033199
# 2019P01                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.025605
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.014930
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.012455
# 2019P02                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.039518
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.036185
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.026949
# 2019P03                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.026949
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.033381
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.031375
# 2019P04                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.034674
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.036169
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.032890
# 2019P05                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.061954
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.048709
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.016570
# 2019P06                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.020949
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.021357
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.013783
# 2019P07                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.089908
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.050836
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.051359
# 2019P08                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.066923
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.058526
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.049282
# 2019P09                        UB READY RICE SPANISH STYLE 12/8.8OZ     0.044611
#                                UB READY RICE SPECIALTY JASMINE 12/240G  0.037967
#                                UB RR WHOLE GRAIN BROWN 12/8.8OZ         0.038821

# %%
temp.reset_index(['Description']).groupby('Description').plot()
# Out:
# Description
# UB READY RICE SPANISH STYLE 12/8.8OZ       AxesSubplot(0.125,0.125;0.775x0.755)
# UB READY RICE SPECIALTY JASMINE 12/240G    AxesSubplot(0.125,0.125;0.775x0.755)
# UB RR WHOLE GRAIN BROWN 12/8.8OZ           AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df[df['Sold to Party Name']=='WAL-MART (EXCL HAWAII)'].groupby(['Plant']).count()
# Out:
#        Unnamed: 0  Actual Goods Issue Year Period  Sold-to party  \
# Plant
# USE2         4715                            4715           4715
# USJ7       194586                          194586         194586
# USV6          283                             283            283
#
#        Sold to Party Name  Customer Hierarchy  Ship-to party  \
# Plant
# USE2                 4715                4715           4715
# USJ7               194586              194586         194586
# USV6                  283                 283            283
#
#        Ship to Party Name  Location (City)  Region  Region Name  Postal Code  \
# Plant
# USE2                 4715             4715    4715         4715         4715
# USJ7               194586           194586  194586       194586       194586
# USV6                  283              283     283          283          283
#
#        Sales Org  Sales Org. Name  Distr Chan  Distr. Channel Name  Division  \
# Plant
# USE2        4715             4715        4715                 4715      4715
# USJ7      194586           194586      194586               194586    194586
# USV6         283              283         283                  283       283
#
#        Division Name  Sales document  Document date  Plant Name  \
# Plant
# USE2            4715            4715           4715        4715
# USJ7          194586          194586         194586      194586
# USV6             283             283            283         283
#
#        Postal Code.1  Location (City).1  Region.1  Region Plant Name  Del No.  \
# Plant
# USE2            4715               4715      4715               4715     4715
# USJ7          194586             194586    194586             194586   194586
# USV6             283                283       283                283      283
#
#        Material  Description  Order qty  Gds mvt qty  Gross weight ord (Lb)  \
# Plant
# USE2       4715         4715       4715         4715                   4715
# USJ7     194586       194586     194586       194586                 194586
# USV6        283          283        283          283                    283
#
#        Gross Weight Dlvrd (Lb)  GSV Delivered  DD_week_num  DD_month  DD_year  \
# Plant
# USE2                      4715           4715         4715      4715     4715
# USJ7                    194586         194586       194586    194586   194586
# USV6                       283            283          283       283      283
#
#            DC  Parent Account  Priority  Correct_DC  approx_unit_lb
# Plant
# USE2     4715            4715      4715        4715            4715
# USJ7   194586          194586    194586      194586          194586
# USV6      283             283       283         283             283

# %%
df[df['Description'].isin(Top3SKU)].pivot_table(values='Order qty', index=['DD_year','DD_month','Description']\
                                                     ,columns='DC',aggfunc = lambda x: x.sum()).fillna(0)['USJ7'].plot()
plt.xticks(rotation=90)
# Out:
# (array([  0.,  20.,  40.,  60.,  80., 100., 120.]),
#  <a list of 7 Text xticklabel objects>)

# %% [markdown]
# # ARIMA

# %% [markdown]
# Three basic criterion for a series to be ***Stationary***
#
# 1) The **mean** of the series should not be a function of time, but be a **constant**. Graph on the left satisfies, but the graph in red has a time dependence.
#
# ![image.png](attachment:image.png)
#
#
# 2) The **variance** of the series should not be a function of time. THis property is known as *homoscedacity*. Notice the varying spread of distribution in the right graph.
#
# ![image.png](attachment:image.png)
#
# 3) The **covariance** of the ith term and the (i+m)th term should not be a function of time. In the following graph, the spread becomes closer as the time increases in the right. Hence, the covariance is **not constant** with time for the right graph.
#
#
# # Why do we care about Stationarity?

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Actual Goods Issue Year Period', 'Sold-to party',
#        'Sold to Party Name', 'Customer Hierarchy', 'Ship-to party',
#        'Ship to Party Name', 'Location (City)', 'Region', 'Region Name',
#        'Postal Code', 'Sales Org', 'Sales Org. Name', 'Distr Chan',
#        'Distr. Channel Name', 'Division', 'Division Name', 'Sales document',
#        'Document date', 'Plant', 'Plant Name', 'Postal Code.1',
#        'Location (City).1', 'Region.1', 'Region Plant Name', 'Del No.',
#        'Material', 'Description', 'Order qty', 'Gds mvt qty',
#        'Gross weight ord (Lb)', 'Gross Weight Dlvrd (Lb)', 'GSV Delivered',
#        'DD_week_num', 'DD_month', 'DD_year', 'DC', 'Parent Account',
#        'Priority', 'Correct_DC', 'approx_unit_lb'],
#       dtype='object')

# %%
len(df['Ship to Party Name'].unique())
# Out:
# 674

# %%
len(df['Description'].unique())
import numpy as np
pd.options.display.float_format = '{:,.4f}'.format
